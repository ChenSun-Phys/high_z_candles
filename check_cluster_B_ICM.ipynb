# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
#from MyUnit import NaturalUnit
from scipy.stats import rv_continuous

# %%
import sys
sys.path.insert(0, '/a/home/cc/students/physics/chensun/Code\
/SN/axions_emcee_v7_LICM_38_realization/')

import icm as icm

# %%
plt.subplots()

# the run with random projections
path = '/a/home/cc/students/physics/chensun/Code/SN/github/chains_back_2/run500_varying_projections/plots/'
filename = '95CL_pts_run500_varying_projections.txt'
data1 = np.loadtxt(path+filename)
plt.plot(10**data1[:,0], 10**data1[:,1]/1.414, label=r"random orientation $\times 1/\sqrt{2}$")

# the run with constant B projection but random domain sizes
path = '/a/home/cc/students/physics/chensun/Code/SN/rev_h0_pan_shoes_bao_clusters_icmB_1e-8_38realizations/plots/'
filename = '95CL_pts_rev_h0_pan_shoes_bao_clusters_icmB_1e-8_38realizations.txt'
data1 = np.loadtxt(path+filename)
plt.plot(10**data1[:,0], 10**data1[:,1], label=r"power law")

# the run with constant B orientation, constant domain size
path = '/a/home/cc/students/physics/chensun/Code/SN/rev_h0_pan_shoes_bao_clusters_icmB_1e-8_LICM10/plots/'
filename = '95CL_pts_rev_h0_pan_shoes_bao_clusters_icmB_1e-8_LICM10.txt'
data2 = np.loadtxt(path+filename)
plt.plot(10**data2[:,0], 10**data2[:,1], label=r"10 kpc")

# the run with constant B orientation, constant domain size
path = '/a/home/cc/students/physics/chensun/Code/SN/rev_h0_pan_shoes_bao_clusters_icmB_1e-8_LICM3p5/plots/'
filename = '95CL_pts_rev_h0_pan_shoes_bao_clusters_icmB_1e-8_LICM3p5.txt'
data3 = np.loadtxt(path+filename)
plt.plot(10**data3[:,0], 10**data3[:,1], '--', label=r"3.5 kpc")

plt.xscale('log')
plt.yscale('log')
plt.ylim(1e-14, 1e-9)
plt.legend(loc=1)
plt.xlabel('$m_a$ [eV]')
plt.ylabel('$g_{a\gamma \gamma}$ [GeV$^{-1}$]')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'$g_{a\\gamma \\gamma}$ [GeV$^{-1}$]')
