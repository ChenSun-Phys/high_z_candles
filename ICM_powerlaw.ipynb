# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
#from MyUnit import NaturalUnit
from scipy.stats import rv_continuous

# %%
import sys
sys.path.insert(0, '/a/home/cc/students/physics\
/chensun/Code/SN/axions_emcee_v5_LICM')

import icm as icm

# %%
# def gen_power_law(n=-1.2, Lmin=3.5, Lmax=10):

#     # define unnormalized distribution
#     def f(x):
#         return x**n

#     # # get the norm
#     # norm = quad(f, Lmin, Lmax)
#     # print(norm)

#     # compute the norm
#     norm = (Lmax**(n+1) - Lmin**(n+1))/(n+1)

#     # define truncated pdf
#     def pdf(x):
#         return f(x)/norm

#     # define the random number generator
#     class powerlaw_gen(rv_continuous):
#         "Truncated power law distribution"

#         def _pdf(self, x):
#             return pdf(x)

#     # initialize the rnd
#     p = powerlaw_gen(name='powerlaw', a=Lmin, b=Lmax)
#     return p

powerlaw = icm.gen_power_law(n=-1.2, Lmax=10, Lmin=3.5)

# %%
# test
totalnumber = 5000
Lmax = 10
Lmin = 3.5
n=-1.2
sample = powerlaw.rvs(size=totalnumber)
plt.subplots()
plt.hist(sample, bins=20, density=True)

# xcheck
L = np.linspace(3.5, 10)
def f(x):
    return x**n

# compute the norm
norm = (Lmax**(n+1) - Lmin**(n+1))/(n+1)

# define truncated pdf
def pdf(x):
    return f(x)/norm

plt.plot(L, pdf(L))
plt.xlabel('L [kpc]')
plt.ylabel
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# time consumption

# %%
# %%timeit
powerlaw.rvs(size=30)
# Out:
# 10 loops, best of 3: 21.8 ms per loop

# %%
# %%timeit
powerlaw = icm.gen_power_law()
powerlaw.rvs(size=30)
# Out:
# 10 loops, best of 3: 22.1 ms per loop

# %%
# this means it's safe to initilize the random 
# number generator every time it's needed.

# %%
# %%timeit
Ntmp = 500;
powerlaw = icm.gen_power_law(n=-1.2, Lmax=10, Lmin=3.5)
L_Arr_raw = powerlaw.rvs(size=Ntmp)
r_Arr_raw = np.cumsum(domains)
r_Arr = r_Arr_raw[np.where(r_Arr_raw < 1800)]
L_Arr = L_Arr_raw[:len(r_Arr)]
# Out:
# 1 loop, best of 3: 396 ms per loop

# %%
0.4*38
# Out:
# 15.200000000000001

# %%
# Ntmp = 500;
# powerlaw = gen_power_law(n=-1.2, Lmax=10, Lmin=3.5)
# L_Arr_raw = powerlaw.rvs(size=Ntmp)
# r_Arr_raw = np.cumsum(domains)
# r_Arr = r_Arr_raw[np.where(r_Arr_raw < r_fin)]
# L_Arr = L_Arr_raw[:len(r_Arr)]
# P_Arr = P(r_Arr, L_Arr)
# Out:
# array([  3.66957892,   9.35977195,  13.42754579,  18.03218419,
#         23.9757687 ,  31.23682003,  40.91849348,  46.77589214,
#         54.65429396,  61.78796634,  69.94733876,  77.83771124,
#         81.42498799,  85.5035223 ,  91.02648612,  99.43151788,
#        108.04455255, 114.02529788, 119.00432484, 122.87957424,
#        127.96123141, 137.91332577, 142.3019301 , 145.81404466,
#        153.37990147, 161.13528233, 164.83327093, 172.40002179,
#        178.47846902, 182.13969686, 190.2274749 , 196.1005553 ,
#        200.87799261, 204.84673314, 212.1605999 , 221.45832947,
#        225.09707403, 230.50455995, 239.8947682 , 246.95858846,
#        256.68617526, 263.23891256, 266.98985404, 272.37895789,
#        277.95982978, 282.79268156, 287.34730313, 291.32344206,
#        295.54184483, 302.28048813, 306.22325192, 315.40600984,
#        322.97372512, 330.21002599, 336.1359212 , 346.11181315,
#        352.0903024 , 355.61645374, 360.90351383, 370.28136343,
# ...
